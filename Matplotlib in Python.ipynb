# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as pyplot

# %%
labels = ("Python", "Java", "C#", "Swift")
sizes = [40, 35, 20, 5]
pyplot.pie(sizes, labels=labels, autopct='%1.f%%', counterclock=False, startangle=110)

#figure
pyplot.show()
